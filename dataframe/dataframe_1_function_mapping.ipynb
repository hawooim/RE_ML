# %% [markdown]
# ## 1) series.apply(function)

# %%
import seaborn as sns

titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = titanic.loc[:, ['age', 'fare']]
df['ten'] = 10
df
# Out:
#       age     fare  ten
# 0    22.0   7.2500   10
# 1    38.0  71.2833   10
# 2    26.0   7.9250   10
# 3    35.0  53.1000   10
# 4    35.0   8.0500   10
# ..    ...      ...  ...
# 886  27.0  13.0000   10
# 887  19.0  30.0000   10
# 888   NaN  23.4500   10
# 889  26.0  30.0000   10
# 890  32.0   7.7500   10
#
# [891 rows x 3 columns]

# %%
def add_10(n):
    return n + 10

def add_two_obj(a, b):
    return a + b

print(add_10(10))
print(add_two_obj(10, 10))
# Out:
# 20
# 20

# %%
sr1 = df['age'].apply(add_10)   # n=all elements in df['age']
sr1.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
sr2 = df['age'].apply(add_two_obj, b=10)   # a=all elements in df['age'], b=10
sr2.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
sr3 = df['age'].apply(lambda x: add_10(x))   # x=df['age']
sr3.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
sr4 = df['age'].apply(lambda a, b: add_two_obj(a, b), b=10)
sr4.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %% [markdown]
# ## 2) dataframe.applymap(function)

# %%
df = titanic.loc[:, ['age', 'fare']]
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
def add_10(n):
    return n + 10

# %%
df1 = df.applymap(add_10)
df1
# Out:
#       age     fare
# 0    32.0  17.2500
# 1    48.0  81.2833
# 2    36.0  17.9250
# 3    45.0  63.1000
# 4    45.0  18.0500
# ..    ...      ...
# 886  37.0  23.0000
# 887  29.0  40.0000
# 888   NaN  33.4500
# 889  36.0  40.0000
# 890  42.0  17.7500
#
# [891 rows x 2 columns]

# %%
df2 = df.applymap(lambda x: add_10(x))
df2
# Out:
#       age     fare
# 0    32.0  17.2500
# 1    48.0  81.2833
# 2    36.0  17.9250
# 3    45.0  63.1000
# 4    45.0  18.0500
# ..    ...      ...
# 886  37.0  23.0000
# 887  29.0  40.0000
# 888   NaN  33.4500
# 889  36.0  40.0000
# 890  42.0  17.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# ## 3) dataframe.apply(function, axis=0)

# %%
df = titanic.loc[:, ['age', 'fare']]
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
# input=series, output=series
def missing_value(series):
    return series.isna()

# %%
df1 = df.apply(missing_value, axis=0)
df1
# Out:
#        age   fare
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 886  False  False
# 887  False  False
# 888   True  False
# 889  False  False
# 890  False  False
#
# [891 rows x 2 columns]

# %%
df2 = df.apply(missing_value)   # axis=0 is default
df2
# Out:
#        age   fare
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 886  False  False
# 887  False  False
# 888   True  False
# 889  False  False
# 890  False  False
#
# [891 rows x 2 columns]

# %%
df3 = df.apply(lambda x: missing_value(x), axis=0)
df3
# Out:
#        age   fare
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 886  False  False
# 887  False  False
# 888   True  False
# 889  False  False
# 890  False  False
#
# [891 rows x 2 columns]

# %%
df4 = df.apply(lambda x: missing_value(x))   # axis=0 is default
df4
# Out:
#        age   fare
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 886  False  False
# 887  False  False
# 888   True  False
# 889  False  False
# 890  False  False
#
# [891 rows x 2 columns]

# %%
# input=series, output=one value
def min_max(x):
    return (x - x.min()) / (x.max() - x.min())

# %%
df1 = df.apply(min_max)   # axis=0 is default
df1
# Out:
#           age      fare
# 0    0.271174  0.014151
# 1    0.472229  0.139136
# 2    0.321438  0.015469
# 3    0.434531  0.103644
# 4    0.434531  0.015713
# ..        ...       ...
# 886  0.334004  0.025374
# 887  0.233476  0.058556
# 888       NaN  0.045771
# 889  0.321438  0.058556
# 890  0.396833  0.015127
#
# [891 rows x 2 columns]

# %%
df1['age'].describe()
# Out:
# count    714.000000
# mean       0.367921
# std        0.182540
# min        0.000000
# 25%        0.247612
# 50%        0.346569
# 75%        0.472229
# max        1.000000
# Name: age, dtype: float64

# %%
df1['fare'].describe()
# Out:
# count    891.000000
# mean       0.062858
# std        0.096995
# min        0.000000
# 25%        0.015440
# 50%        0.028213
# 75%        0.060508
# max        1.000000
# Name: fare, dtype: float64

# %% [markdown]
# ## 4) daraframe.apply(function, axis=1)

# %%
df = titanic.loc[:, ['age', 'fare']]
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
def add_two_obj(a, b):
    return a + b

# %%
# x=df, a=df['age'], b=df['fare']
df['add'] = df.apply(lambda x: add_two_obj(x['age'], x['fare']), axis=1)
df.head()
# Out:
#     age     fare       add
# 0  22.0   7.2500   29.2500
# 1  38.0  71.2833  109.2833
# 2  26.0   7.9250   33.9250
# 3  35.0  53.1000   88.1000
# 4  35.0   8.0500   43.0500

# %%
# not working this way. use lambda.
# df['age'].apply(add_two_obj, b=df['fare'], axis=1)

# %% [markdown]
# ## 5) dataframe.pipe(function)

# %%
df = titanic.loc[:, ['age', 'fare']]
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
# input: df, output: df
def missing_value(x):
    return x.isna()

# input: df, output: series
def missing_count(x):
    return missing_value(x).sum()

# input: df, output: single value
def total_number_missing(x):
    return missing_count(x).sum()

# %%
df.pipe(missing_value)
# Out:
#        age   fare
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 886  False  False
# 887  False  False
# 888   True  False
# 889  False  False
# 890  False  False
#
# [891 rows x 2 columns]

# %%
df.pipe(missing_count)
# Out:
# age     177
# fare      0
# dtype: int64

# %%
df.pipe(total_number_missing)
# Out:
# 177
